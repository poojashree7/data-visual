# %%
arr=[10,20,40,50]
arr.insert(2,30)
print(arr)
# Out:
# [10, 20, 30, 40, 50]

# %%
arr=[10,20,30]
for elements in arr:
  print(elements)
# Out:
# 10
# 20
# 30

# %%
arr=[10,20,30,40,50]
arr.remove(30)
print(arr)
# Out:
# [10, 20, 40, 50]

# %%
arr=[10,20,30,40,50]
key=30
if key in arr:
    print("element found")
else:
    print("element not found")
# Out:
# element found

# %%
arr=[10,20,30,40,50]
key=60
if key in arr:
    print("element found")
else:
    print("element not found")
# Out:
# element not found

# %%
arr=[10,20,30,40,50]
arr[2]=35
print(arr)
# Out:
# [10, 20, 35, 40, 50]

# %%
arr=[10,30,50,40,20]
arr.sort()
print(arr)
# Out:
# [10, 20, 30, 40, 50]

# %%
arr=[10,20,30,40,50]
print(arr[0])
print(arr[-1])
print(arr[2])
print(arr[2:5])
# Out:
# 10
# 50
# 30
# [30, 40, 50]
