# %%
import pandas as pd
s=pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s=pd.Series([100,200,300], index=['A','B','C'])
print(s)
# Out:
# A    100
# B    200
# C    300
# dtype: int64

# %%
data={'maths':90,
      'physic':85,
      'chemistry':88}
s=pd.Series(data)
print(s)
# Out:
# maths        90
# physic       85
# chemistry    88
# dtype: int64

# %%
s=pd.Series([10,20,30,40])
print(s[0])
# Out:
# 10

# %%
s=pd.Series([100,200,300], index=['A','B','C'])
print(s['B'])
# Out:
# 200
